# %% [markdown]
# #### 1. How and when to use the AutoSum command in excel?
# 1. Home tab > Editing group > AutoSum:
# ![autosum-button-excel.png](attachment:autosum-button-excel.png)

# %% [markdown]
# 2. Formulas tab > Function Library group > AutoSum:
# ![autosum-button-excel2.png](attachment:autosum-button-excel2.png)

# %% [markdown]
# * Whenever we need to sum a single range of cells, whether a column, row or several adjacent columns or rows, you can have Excel AutoSum to automatically make an appropriate SUM formula for you.
#
# 1. Select a cell next to the numbers you want to sum:
#   * To sum a column, select the cell immediately below the last value in the     column.
#   * To sum a row, select the cell to the right of the last number in the row.
#   ![excel-autosum-column-row.png](attachment:excel-autosum-column-row.png)

# %% [markdown]
# 2. Select a cell next to the numbers you want to sum:
#   * To sum a column, select the cell immediately below the last value in the      column.
#   * To sum a row, select the cell to the right of the last number in the row.
#   ![use-autosum-excel.png](attachment:use-autosum-excel.png)

# %% [markdown]
# 3. Press the Enter key to complete the formula.
# ![sum-formula-inserted.png](attachment:sum-formula-inserted.png)

# %% [markdown]
# #### 2. What is the shortcut key to perform AutoSum?

# %% [markdown]
# ![excel-sum-shortcut.png](attachment:excel-sum-shortcut.png)
#
#
# * Pressing the Equal Sign key while holding the Alt key inserts a Sum formula in a selected cells(s) exactly like pressing the AutoSum button on the ribbon does, and then you hit the Enter key to complete the formula.

# %% [markdown]
# #### 3. How do you get rid of Formula that omits adjacent cells?

# %% [markdown]
# 1. Open Excel and then click on File.
# 2. Go to Options and then select Formulas.
# 3. Look for Error checking rules and uncheck Formulas which omit cells in a region.
# 4. Click OK.

# %% [markdown]
# #### 4. How do you select non-adjacent cells in Excel 2016?

# %% [markdown]
# * Select Non-Adjacent Cells with Keyboard and Mouse
#
# 1. With your mouse, click the first cell you want to highlight. This cell becomes the active cell.
#
# 2. Press and hold the Ctrl key on the keyboard.
#
# 3. Click the rest of the cells you want to highlight.
#
# 4. Once the desired cells are highlighted, release the Ctrl key.
#
# 5. Do not click anywhere else with the mouse pointer once you release the Ctrl key or you will clear the highlight from the selected cells.
#
# 6. If you release the Ctrl key too soon and wish to highlight more cells, press and hold the Ctrl key again and click the additional cell(s).

# %% [markdown]
# #### 5. What happens if you choose a column, hold down the Alt key and press the letters ocw in quick succession?

# %% [markdown]
# * The column width dialogue box opens allowing you to set the exact width of the column
#     You can insert a value in the column width dialogue box for how wide you would like a column to be. This is especially useful if you have several non-adjacent columns that you need to be the same width.

# %% [markdown]
# #### 6. If you right-click on a row reference number and click on Insert, where will the row be added?

# %% [markdown]
# ans: when we right click on row reference number and click on insert the row will be added on the top of that selected refernce number.
